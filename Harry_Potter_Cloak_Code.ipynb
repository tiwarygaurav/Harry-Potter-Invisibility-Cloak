# %%
import cv2
import numpy as np

#Importing necessssssary module

#Background capturing process
cap = cv2.VideoCapture(0)

# %%
import time
time.sleep(3)

# %%
ret, background = cap.read()
background = np.flip(background, axis=1)

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Flip the frame horizontally (mirror image)
    frame = np.flip(frame, axis=1)

    # Convert the frame from BGR to HSV
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define the range of the color of the cloak in HSV
    # Here, we assume the cloak is red. You may need to adjust these values.
    lower_red = np.array([0, 120, 70])
    upper_red = np.array([10, 255, 255])
    mask1 = cv2.inRange(hsv, lower_red, upper_red)

    lower_red = np.array([170, 120, 70])
    upper_red = np.array([180, 255, 255])
    mask2 = cv2.inRange(hsv, lower_red, upper_red)

    # Combine the masks to get the final mask
    mask = mask1 + mask2

    # Refine the mask
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, np.ones((3, 3), np.uint8))
    mask = cv2.morphologyEx(mask, cv2.MORPH_DILATE, np.ones((3, 3), np.uint8))

    # Create the inverse mask
    mask_inv = cv2.bitwise_not(mask)

    # Segment the cloak part
    cloak = cv2.bitwise_and(background, background, mask=mask)

    # Segment the non-cloak part
    non_cloak = cv2.bitwise_and(frame, frame, mask=mask_inv)

    # Combine both parts
    final_output = cv2.addWeighted(cloak, 1, non_cloak, 1, 0)

    # Display the output
    cv2.imshow("Invisibility Cloak", final_output)

    # Break the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()

# %%
$
import cv2
import numpy as np
import time

# Background capturing process
cap = cv2.VideoCapture(0)

time.sleep(3)
ret, background = cap.read()
background = np.flip(background, axis=1)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Flip the frame horizontally (mirror image)
    frame = np.flip(frame, axis=1)

    # Convert the frame from BGR to HSV
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define the range of the color of the cloak in HSV
    # Here, we assume the cloak is blue. You may need to adjust these values.
    lower_blue = np.array([100, 150, 0])
    upper_blue = np.array([140, 255, 255])
    mask = cv2.inRange(hsv, lower_blue, upper_blue)

    # Refine the mask
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, np.ones((3, 3), np.uint8))
    mask = cv2.morphologyEx(mask, cv2.MORPH_DILATE, np.ones((3, 3), np.uint8))

    # Create the inverse mask
    mask_inv = cv2.bitwise_not(mask)

    # Segment the cloak part
    cloak = cv2.bitwise_and(background, background, mask=mask)

    # Segment the non-cloak part
    non_cloak = cv2.bitwise_and(frame, frame, mask=mask_inv)

    # Combine both parts
    final_output = cv2.addWeighted(cloak, 1, non_cloak, 1, 0)

    # Display the output
    cv2.imshow("Invisibility Cloak", final_output)

    # Break the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
